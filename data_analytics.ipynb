# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Product Data Analytics"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "\n",
    "# Reasoning: Set plot style for better aesthetics. [cite: 52]\n",
    "sns.set_style('whitegrid')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Load Data\n",
    "Reasoning: Load the dataset into a pandas DataFrame for analysis. For this example, we'll use a mock DataFrame representing the structure. [cite: 52]"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "data = {\n",
    "    'title': ['Oak Chair', 'Steel Table', 'Wool Rug', 'Glass Lamp', 'Leather Sofa', 'Pine Shelf'],\n",
    "    'price': [250, 180, 300, 80, 1200, 150],\n",
    "    'categories': ['Furniture', 'Furniture', 'Home Decor', 'Lighting', 'Furniture', 'Furniture'],\n",
    "    'material': ['Wood', 'Metal', 'Wool', 'Glass', 'Leather', 'Wood']\n",
    "}\n",
    "df = pd.DataFrame(data)\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Price Distribution Analysis\n",
    "Reasoning: Understand the distribution of product prices to identify the price range and common price points. [cite: 52]"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "plt.figure(figsize=(10, 6))\n",
    "sns.histplot(df['price'], kde=True, bins=20)\n",
    "plt.title('Distribution of Product Prices')\n",
    "plt.xlabel('Price ($)')\n",
    "plt.ylabel('Frequency')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Product Count by Category\n",
    "Reasoning: Visualize the number of products in each category to understand the dataset's composition. [cite: 52]"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "plt.figure(figsize=(10, 6))\n",
    "sns.countplot(y=df['categories'], order=df['categories'].value_counts().index)\n",
    "plt.title('Number of Products per Category')\n",
    "plt.xlabel('Count')\n",
    "plt.ylabel('Category')\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Product Data Analytics"
#       8    ]
#       9   },
#      10   {
#      11    "cell_type": "code",
# ---> 12    "execution_count": null,
#      13    "metadata": {},
#      14    "outputs": [],
#      15    "source": [
#      16     "import pandas as pd\n",
#      17     "import matplotlib.pyplot as plt\n",
#      18     "import seaborn as sns\n",
#      19     "\n",
#      20     "# Reasoning: Set plot style for better aesthetics. [cite: 52]\n",
#      21     "sns.set_style('whitegrid')"
#      22    ]
#      23   },
#      24   {
#      25    "cell_type": "markdown",
#      26    "metadata": {},
#      27    "source": [
# ...
